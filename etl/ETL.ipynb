# %%
import pandas as pd 
pd.set_option("display.max_columns", None)
pd.set_option("display.float_format", "{:.0f}".format)

# %%
#Extraction
df = pd.read_csv("C:/Users/Lenovo/Desktop/avito-data-pipeline/data/archive/avito_cars_dirty.csv")

print("Initial shape:", df.shape)
df.info()
# Out:
# Initial shape: (99506, 17)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99506 entries, 0 to 99505
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   annee              99191 non-null  object
#  1   boite              98945 non-null  object
#  2   carburant          99221 non-null  object
#  3   kilometrage        99167 non-null  object
#  4   marque             99163 non-null  object
#  5   modele             99163 non-null  object
#  6   nombre_portres     88465 non-null  float64
#  7   origine            87749 non-null  object
#  8   premiere_main      86110 non-null  object
#  9   puissance_fiscale  98956 non-null  object
#  10  etat               95567 non-null  object
#  11  titre              99506 non-null  object
#  12  description        99506 non-null  object
#  13  prix               99506 non-null  int64
#  14  boutique           99500 non-null  object
#  15  equipements        68718 non-null  object
#  16  url                99506 non-null  object
# dtypes: float64(1), int64(1), object(15)
# memory usage: 12.9+ MB
